# %% [markdown]
# # K nearest neighbors

# %% [markdown]
# KNN falls in the supervised learning family of algorithms. Informally, this means that we are given a labelled dataset consiting of training observations (x, y) and would like to capture the relationship between x and y. More formally, our goal is to learn a function h: X→Y so that given an unseen observation x, h(x) can confidently predict the corresponding output y.
#
# In this module we will explore the inner workings of KNN, choosing the optimal K values and using KNN from scikit-learn.

# %% [markdown]
# ## Overview
#
# 1. Read the problem statement.
#
# 2. Get the dataset.
#
# 3. Explore the dataset.
#
# 4. Pre-processing of dataset.
#
# 5. Visualization
#
# 6. Transform the dataset for building machine learning model.
#
# 7. Split data into train, test set.
#
# 8. Build Model.
#
# 9. Apply the model.
#
# 10. Evaluate the model.
#
# 11. Finding Optimal K value
#
# 12. Repeat 7, 8, 9 steps.

# %% [markdown]
# ### Dataset
#
# The data set we’ll be using is the Iris Flower Dataset which was first introduced in 1936 by the famous statistician Ronald Fisher and consists of 50 observations from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals.
#
# **Download the dataset here:**
# - https://www.kaggle.com/uciml/iris
#
# **Train the KNN algorithm to be able to distinguish the species from one another given the measurements of the 4 features.**

# %% [markdown]
# ## Load data

# %% [markdown]
# ### Question 1
#
# Import the data set and print 10 random rows from the data set
#
# Hint: use **sample()** function to get random rows

# %%
import pandas as pd
import numpy as np
Iris_df = pd.read_csv('Iris.csv')
Iris_df.sample(n=10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 56    57            6.3           3.3            4.7           1.6
# 106  107            4.9           2.5            4.5           1.7
# 139  140            6.9           3.1            5.4           2.1
# 50    51            7.0           3.2            4.7           1.4
# 93    94            5.0           2.3            3.3           1.0
# 131  132            7.9           3.8            6.4           2.0
# 28    29            5.2           3.4            1.4           0.2
# 36    37            5.5           3.5            1.3           0.2
# 148  149            6.2           3.4            5.4           2.3
# 119  120            6.0           2.2            5.0           1.5
#
#              Species
# 56   Iris-versicolor
# 106   Iris-virginica
# 139   Iris-virginica
# 50   Iris-versicolor
# 93   Iris-versicolor
# 131   Iris-virginica
# 28       Iris-setosa
# 36       Iris-setosa
# 148   Iris-virginica
# ...

# %% [markdown]
# ## Data Pre-processing

# %% [markdown]
# ### Question 2 - Estimating missing values
#
# Its not good to remove the records having missing values all the time. We may end up loosing some data points. So, we will have to see how to replace those missing values with some estimated values (median)

# %% [markdown]
# Calculate the number of missing values per column
# - don't use loops

# %%
Iris_df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# Fill missing values with median of that particular column

# %%
Iris_df.fillna(Iris_df.median(),inplace = True)
Iris_df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %% [markdown]
# ### Question 3
#
# Observe the association of each independent variable with target variable and drop variables from feature set having correlation in range -0.1 to 0.1 with target variable.
#
# Hint: use **corr()**

# %%
from sklearn.preprocessing import LabelEncoder
sns.set(style="ticks", color_codes=True)
lb_species = LabelEncoder()
Iris_df["Species"] = lb_species.fit_transform(Iris_df["Species"])
Iris_df.drop(Iris_df.loc[:, (Iris_df.corr()['Species'].between(-0.1, 0.1))], axis = 1, inplace = True)
Iris_df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0              5.1           3.5            1.4           0.2        0
# 1              4.9           3.0            1.4           0.2        0
# 2              4.7           3.2            1.3           0.2        0
# 3              4.6           3.1            1.5           0.2        0
# 4              5.0           3.6            1.4           0.2        0
# 5              5.4           3.9            1.7           0.4        0
# 6              4.6           3.4            1.4           0.3        0
# 7              5.0           3.4            1.5           0.2        0
# 8              4.4           2.9            1.4           0.2        0
# 9              4.9           3.1            1.5           0.1        0
# 10             5.4           3.7            1.5           0.2        0
# 11             4.8           3.4            1.6           0.2        0
# ...

# %% [markdown]
# ### Question 4
#
# Observe the independent variables variance and drop such variables having no variance or almost zero variance (variance < 0.1). They will be having almost no influence on the classification
#
# Hint: use **var()**

# %%
Iris_df.drop(Iris_df.loc[:,Iris_df[:-1].var() < 0.1], axis = 1, inplace = True)
Iris_df.shape
# Out:
# (150, 6)

# %% [markdown]
# ### Question 5
#
# Plot the scatter matrix for all the variables.
#
# Hint: use **pandas.plotting.scatter_matrix()**
#
# you can also use pairplot()

# %%
sns.pairplot(Iris_df)

# %% [markdown]
# ## Build Model

# %% [markdown]
# ### Question 6
#
# Build the model and train and test on training and test sets respectively using **scikit-learn**.
#
# Print the Accuracy of the model with different values of **k = 3, 5, 9**
#
# Hint: For accuracy you can check **accuracy_score()** in scikit-learn

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
Iris_df = pd.read_csv("Iris.csv")
Iris_df = Iris_df.drop('Id',axis=1)
Iris_df.head() 
y = Iris_df['Species']
X = Iris_df.drop('Species',axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20,stratify = y)

knn3=KNeighborsClassifier(n_neighbors=3)

knn3.fit(X_train,y_train)
y_pred = knn3.predict(X_test)

print("What is the Testing Accuracy for K = 3")
print(accuracy_score(y_test,y_pred))
# Out:
# What is the Testing Accuracy for K = 3
# 0.9666666666666667

# %%
knn5=KNeighborsClassifier(n_neighbors=5)

knn5.fit(X_train,y_train)
y_pred = knn5.predict(X_test)

print("What is the Testing Accuracy for K = 5")
print(accuracy_score(y_test,y_pred))
# Out:
# What is the Testing Accuracy for K = 5
# 0.9666666666666667

# %%
knn9=KNeighborsClassifier(n_neighbors=9)

knn9.fit(X_train,y_train)
y_pred = knn9.predict(X_test)

print("What is the Testing Accuracy for K = 9")
print(accuracy_score(y_test,y_pred))
# Out:
# What is the Testing Accuracy for K = 9
# 0.9666666666666667

# %% [markdown]
# # Breast cancer dataset

# %% [markdown]
# ## Read data

# %% [markdown]
# ### Question 1
# Read the data given in bc2.csv file

# %%
Bc_df = pd.read_csv("bc2.csv")

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### Question 2
# Observe the no.of records in dataset and type of each column

# %%
Bc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 11 columns):
# ID                             699 non-null int64
# ClumpThickness                 699 non-null int64
# Cell Size                      699 non-null int64
# Cell Shape                     699 non-null int64
# Marginal Adhesion              699 non-null int64
# Single Epithelial Cell Size    699 non-null int64
# Bare Nuclei                    699 non-null object
# Normal Nucleoli                699 non-null int64
# Bland Chromatin                699 non-null int64
# Mitoses                        699 non-null int64
# Class                          699 non-null int64
# dtypes: int64(10), object(1)
# memory usage: 57.4+ KB

# %% [markdown]
# ### Question 3
# Use summary statistics to check if missing values, outlier and encoding treament is necessary
#
# Hint: use **describe()**

# %%
Bc_df.describe()
# Out:
#                  ID  ClumpThickness   Cell Size  Cell Shape  \
# count  6.990000e+02      699.000000  699.000000  699.000000
# mean   1.071704e+06        4.417740    3.134478    3.207439
# std    6.170957e+05        2.815741    3.051459    2.971913
# min    6.163400e+04        1.000000    1.000000    1.000000
# 25%    8.706885e+05        2.000000    1.000000    1.000000
# 50%    1.171710e+06        4.000000    1.000000    1.000000
# 75%    1.238298e+06        6.000000    5.000000    5.000000
# max    1.345435e+07       10.000000   10.000000   10.000000
#
#        Marginal Adhesion  Single Epithelial Cell Size  Normal Nucleoli  \
# count         699.000000                   699.000000       699.000000
# mean            2.806867                     3.216023         3.437768
# std             2.855379                     2.214300         2.438364
# min             1.000000                     1.000000         1.000000
# ...

# %% [markdown]
# #### Check Missing Values

# %%
Bc_df.isnull().sum()
# Out:
# ID                             0
# ClumpThickness                 0
# Cell Size                      0
# Cell Shape                     0
# Marginal Adhesion              0
# Single Epithelial Cell Size    0
# Bare Nuclei                    0
# Normal Nucleoli                0
# Bland Chromatin                0
# Mitoses                        0
# Class                          0
# dtype: int64

# %% [markdown]
# ### Question 4
# #### Check how many `?` are there in Bare Nuclei feature (they are also unknown or missing values).

# %%
Bc_df[Bc_df['Bare Nuclei'] == '?'].count()
# Out:
# ID                             0
# ClumpThickness                 0
# Cell Size                      0
# Cell Shape                     0
# Marginal Adhesion              0
# Single Epithelial Cell Size    0
# Bare Nuclei                    0
# Normal Nucleoli                0
# Bland Chromatin                0
# Mitoses                        0
# Class                          0
# dtype: int64

# %% [markdown]
# #### Replace them with the 'top' value of the describe function of Bare Nuclei feature
#
# Hint: give value of parameter include='all' in describe function

# %%
#Bc_df['Bare Nuclei'].describe(include= all)
Bc_df['Bare Nuclei'].replace('?',Bc_df['Bare Nuclei'].describe(include=all)['top'],inplace = True)
Bc_df
# Out:
#      ClumpThickness  Cell Size  Cell Shape  Marginal Adhesion  \
# 0                 5          1           1                  1
# 1                 5          4           4                  5
# 2                 3          1           1                  1
# 3                 6          8           8                  1
# 4                 4          1           1                  3
# 5                 8         10          10                  8
# 6                 1          1           1                  1
# 7                 2          1           2                  1
# 8                 2          1           1                  1
# 9                 4          2           1                  1
# 10                1          1           1                  1
# 11                2          1           1                  1
# 12                5          3           3                  3
# 13                1          1           1                  1
# ...

# %% [markdown]
# ### Question 5
# #### Find the distribution of target variable (Class)

# %%
print(Bc_df['Class'].value_counts())
sns.distplot(Bc_df['Class'], bins = 2)
# Out:
# 2    458
# 4    241
# Name: Class, dtype: int64

# %% [markdown]
# #### Plot the distribution of target variable using histogram

# %%
Bc_df['Class'].hist()

# %% [markdown]
# #### Convert the datatype of Bare Nuclei to `int`

# %%
Bc_df['Bare Nuclei'] = Bc_df['Bare Nuclei'].astype(int)

# %% [markdown]
# ## Scatter plot

# %% [markdown]
# ### Question 6
# Plot Scatter Matrix to understand the distribution of variables and check if any variables are collinear and drop one of them.

# %%
Bc_df.corr()
# Cell Shape and Cell Size are highly correlated - 0.906882
# Single Epithelian Cell Size and Cell Size - 0.751799
# ID is dropped due to uniqueness while building model
# Out:
#                              ClumpThickness  Cell Size  Cell Shape  \
# ClumpThickness                     1.000000   0.644913    0.654589
# Cell Size                          0.644913   1.000000    0.906882
# Cell Shape                         0.654589   0.906882    1.000000
# Marginal Adhesion                  0.486356   0.705582    0.683079
# Single Epithelial Cell Size        0.521816   0.751799    0.719668
# Bare Nuclei                        0.590008   0.686673    0.707474
# Normal Nucleoli                    0.558428   0.755721    0.735948
# Bland Chromatin                    0.535835   0.722865    0.719446
# Mitoses                            0.350034   0.458693    0.438911
# Class                              0.716001   0.817904    0.818934
#
#                              Marginal Adhesion  Single Epithelial Cell Size  \
# ClumpThickness                        0.486356                     0.521816
# ...

# %% [markdown]
# ## Train test split

# %% [markdown]
# ### Question 7
# #### Divide the dataset into feature set and target set

# %%
y = Bc_df['Class'] # Target Variable ID is removed from the Dataframe due to uniqueness
X = Bc_df.drop('Class',axis=1) # Independent Variables

# %% [markdown]
# #### Divide the Training and Test sets in 70:30

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30,stratify = y)

# %% [markdown]
# ## Scale the data

# %% [markdown]
# ### Question 8
# Standardize the data
#
# Hint: use **StandardScaler()**

# %%
from sklearn.preprocessing import StandardScaler
sc.fit(X_train)
scaledX_train = sc.transform(X_train)
sc.fit(X_test)
scaledX_test = sc.transform(X_test)
# Out:
# C:\Users\agopalakrishnan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int32, int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\agopalakrishnan\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: Data with input dtype int32, int64 were all converted to float64 by StandardScaler.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\agopalakrishnan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int32, int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# ...

# %% [markdown]
# ## Build Model

# %% [markdown]
# ### Question 9
#
# Build the model and train and test on training and test sets respectively using **scikit-learn**.
#
# Print the Accuracy of the model with different values of **k = 3, 5, 9**
#
# Hint: For accuracy you can check **accuracy_score()** in scikit-learn

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
knn=KNeighborsClassifier(n_neighbors=3)

knn.fit(scaledX_train,y_train)
y_pred = knn.predict(scaledX_test)

print("What is the Testing Accuracy for K = 3")
print(accuracy_score(y_test,y_pred))
# Out:
# What is the Testing Accuracy for K = 3
# 0.9666666666666667

# %%
knn=KNeighborsClassifier(n_neighbors=5)

knn5.fit(scaledX_train,y_train)
y_pred = knn5.predict(scaledX_test)

print("What is the Testing Accuracy for K = 5")
print(accuracy_score(y_test,y_pred))
# Out:
# What is the Testing Accuracy for K = 5
# 0.9523809523809523

# %%
knn=KNeighborsClassifier(n_neighbors=9)

knn5.fit(scaledX_train,y_train)
y_pred = knn5.predict(scaledX_test)

print("What is the Testing Accuracy for K = 9")
print(accuracy_score(y_test,y_pred))
# Out:
# What is the Testing Accuracy for K = 9
# 0.9523809523809523
